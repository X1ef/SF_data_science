# %% [markdown]
# <a href="https://colab.research.google.com/github/X1ef/SF_data_science/blob/main/sf_pandas_12_11_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Работа с Pandas

# %% [markdown]
# Булыгин Олег:
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Мой канал в ТГ по Python](https://t.me/pythontalk_ru)
# * [Чат канала](https://t.me/pythontalk_chat)
# * [Блог в Телетайпе](https://teletype.in/@pythontalk)
# * [PythonTalk на Кью](https://yandex.ru/q/loves/pythontalk/)

# %% [markdown]
# ## План
# В рамках воркфлоу работы с открытым датафреймом по реальным транзакциям британского онлайн-магазина подарков. Реализуем набор аналитических действий и решим задачи:
# - посчитаем статистику по странам;
# - проанализируем выручку;
# - изучим статистику по клиентам;
# - проанализируем динамику среднего чека;
# - просегментируем товары по стоимости;
# - сделаем когортный анализ и анализ удержания клиентов (уже непросто!).
#
# Пройдя по этим шагам повторим:
# - базовую работу с датами;
# - преобразование типов;
# - сортировку;
# - группировку и сводные таблицы;
# - объединение датафреймов.

# %%
# импортируем pandas
import pandas as pd

# %% [markdown]
# ### Открытие и знакомство с данными

# %%
# читаем данные из csv, который находится в zip-файле на github
url = 'https://github.com/obulygin/SkillFactory/blob/main/ecommerce-data.zip?raw=true'
df = pd.read_csv(url, encoding='ISO-8859-1', compression='zip')

# %%
# смотрим первые 5 строк таблицы
display(df.head())
# смотрим последние 5 строк таблицы
display(df.tail())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# рассчитываем базовые статистики по каждому числовому признаку
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ### Избавимся от отрицательных значений

# %%
# оставляем данные только с положительными ценами на товар и количеством
df = df[(df['UnitPrice'] > 0) & (df['Quantity'] > 0)]
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  530104.000000  530104.000000  397884.000000
# mean       10.542037       3.907625   15294.423453
# std       155.524124      35.915681    1713.141560
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %% [markdown]
# ### Избавимся от дубликатов в данных

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 530104, dtype: bool

# %%
# посмотрим, сколько у нас повторов
print(df.duplicated().sum())
# Out:
# 5226

# %%
# сколько всего строк?
print(df.shape)
# Out:
# (530104, 8)

# %%
# удалим дубли и проверим
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (524878, 8)

# %% [markdown]
# ### Поправим типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524878 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    524878 non-null  object
#  1   StockCode    524878 non-null  object
#  2   Description  524878 non-null  object
#  3   Quantity     524878 non-null  int64
#  4   InvoiceDate  524878 non-null  object
#  5   UnitPrice    524878 non-null  float64
#  6   CustomerID   392692 non-null  float64
#  7   Country      524878 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.0+ MB

# %%
# почему ошибка?
df['CustomerID'] = df['CustomerID'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-13-45a7e488ec33> in <module>
#       1 # почему ошибка?
# ----> 2 df['CustomerID'] = df['CustomerID'].astype('int64')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1212     if not np.isfinite(values).all():
#    1213         raise IntCastingNaNError(
# -> 1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#    1216     return values.astype(dtype, copy=copy)
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
# Nullable datatypes: https://pandas.pydata.org/pandas-docs/stable/user_guide/integer_na.html
df['CustomerID'] = df['CustomerID'].astype('Int64')

# %%
# переведем даты из строкового формата в datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524878 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    524878 non-null  object
#  1   StockCode    524878 non-null  object
#  2   Description  524878 non-null  object
#  3   Quantity     524878 non-null  int64
#  4   InvoiceDate  524878 non-null  datetime64[ns]
#  5   UnitPrice    524878 non-null  float64
#  6   CustomerID   392692 non-null  Int64
#  7   Country      524878 non-null  object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 36.5+ MB

# %% [markdown]
# ### Изучаем статистику по странам

# %%
# считаем сколько транзакций было по странам при помощи value_counts
df['Country'].value_counts()
# Out:
# United Kingdom          479985
# Germany                   9025
# France                    8392
# EIRE                      7879
# Spain                     2479
# Netherlands               2359
# Belgium                   2031
# Switzerland               1958
# Portugal                  1492
# Australia                 1181
# Norway                    1071
# Italy                      758
# Channel Islands            747
# Finland                    685
# Cyprus                     603
# Sweden                     450
# Unspecified                442
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     292
# Hong Kong                  280
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
# считаем сколько уникальных клиентов в странах
countries = df.groupby('Country')['CustomerID'].nunique().sort_values(ascending=False)
countries
# Out:
# Country
# United Kingdom          3920
# Germany                   94
# France                    87
# Spain                     30
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     14
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Channel Islands            9
# Denmark                    9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Greece                     4
# EIRE                       3
# Israel                     3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Lithuania                  1
# Czech Republic             1
# Lebanon                    1
# RSA                        1
# Saudi Arabia               1
# Singapore                  1
# Iceland                    1
# Brazil                     1
# European Community         1
# Hong Kong                  0
# Name: CustomerID, dtype: int64

# %% [markdown]
# #### Практика. Определяем топ-5 лояльных клиентов по количеству покупок

# %%
df.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False).head()
# Out:
# CustomerID
# 12748    209
# 14911    201
# 17841    124
# 13089     97
# 14606     93
# Name: InvoiceNo, dtype: int64

# %%
df.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False).head(5)
# Out:
# CustomerID
# 12748    209
# 14911    201
# 17841    124
# 13089     97
# 14606     93
# Name: InvoiceNo, dtype: int64

# %%
df.groupby('Country')['InvoiceNo'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          18019
# Germany                   457
# France                    392
# EIRE                      288
# Belgium                    98
# Netherlands                94
# Spain                      90
# Portugal                   58
# Australia                  57
# Switzerland                54
# Finland                    41
# Italy                      38
# Norway                     36
# Sweden                     36
# Channel Islands            26
# Japan                      19
# Poland                     19
# Denmark                    18
# Austria                    17
# Cyprus                     16
# Unspecified                13
# Hong Kong                  11
# Israel                      8
# Iceland                     7
# Singapore                   7
# Canada                      6
# USA                         5
# Malta                       5
# Greece                      5
# European Community          4
# Lithuania                   4
# Bahrain                     3
# United Arab Emirates        3
# Czech Republic              2
# Lebanon                     1
# Brazil                      1
# RSA                         1
# Saudi Arabia                1
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ### Создадим временные признакми

# %%
# добавим месяц покупки в новый столбец при помощи dt.strftime('%Y - %m')
df['InvoiceMonth'] = df['InvoiceDate'].dt.strftime('%Y-%m') 
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom      2010-12
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom      2010-12
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# ...                    ...        ...         ...             ...          ...
# 541904 2011-12-09 12:50:00       0.85       12680          France      2011-12
# 541905 2011-12-09 12:50:00       2.10       12680          France      2011-12
# 541906 2011-12-09 12:50:00       4.15       12680          France      2011-12
# 541907 2011-12-09 12:50:00       4.15       12680          France      2011-12
# 541908 2011-12-09 12:50:00       4.95       12680          France      2011-12
#
# [524878 rows x 9 columns]

# %%
# уникальные покупатели по месяцам
df.groupby('InvoiceMonth')['CustomerID'].nunique().plot()

# %%
# зафиксируем дни недели
df['DayOfWeek'] = df['InvoiceDate'].dt.dayofweek + 1
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
#        InvoiceMonth  DayOfWeek
# 0           2010-12          3
# 1           2010-12          3
# 2           2010-12          3
# 3           2010-12          3
# 4           2010-12          3
# ...             ...        ...
# 541904      2011-12          5
# 541905      2011-12          5
# 541906      2011-12          5
# 541907      2011-12          5
# 541908      2011-12          5
#
# [524878 rows x 10 columns]

# %%
# посчитаем количество заказов по дням недели
df.groupby('DayOfWeek')['InvoiceNo'].nunique().plot(kind='bar')

# %% [markdown]
# #### Практика. Изучим динамику количества покупок по часам

# %%
df['DayHour'] = df['InvoiceDate'].dt.hour
df.groupby('DayHour')['InvoiceNo'].nunique().plot()

# %%
df['InvoiceHour'] = df['InvoiceDate'].dt.hour 
df.groupby('InvoiceHour')['InvoiceNo'].nunique().plot()

# %% [markdown]
# ### Посчитаем выручку

# %%
# создадим новый столбец
df['Revenue'] = df['Quantity'] * df['UnitPrice']

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom      2010-12
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom      2010-12
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
#
#    DayOfWeek  DayHour  InvoiceHour  Revenue
# 0          3        8            8    15.30
# 1          3        8            8    20.34
# 2          3        8            8    22.00
# 3          3        8            8    20.34
# 4          3        8            8    20.34

# %%
# выручка по месяцам
df.groupby('InvoiceMonth')['Revenue'].sum().plot()

# %% [markdown]
# #### Практика. Найдите 3 страны, которые принесли максимальную выручку после UK

# %%
df.groupby('Country')['Revenue'].sum().sort_values(ascending=False)[1:4]
# Out:
# Country
# Netherlands    285446.34
# EIRE           283140.52
# Germany        228678.40
# Name: Revenue, dtype: float64

# %%
df.groupby('Country')['Revenue'].sum().sort_values(ascending = False)[1:4]
# Out:
# Country
# Netherlands    285446.34
# EIRE           283140.52
# Germany        228678.40
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Сегменты товаров по стоимости

# %%
# напишем функцию для сегментации товаров
def price_segment(row):
    if row < 5:
        return 'cheap' 
    elif 5 <= row < 25:
        return 'lower-middle'
    elif 25 <= row < 100:
        return 'upper-middle'
    elif row >= 100:
        return 'expensive'
 

df['PriceSegment'] = df['UnitPrice'].apply(price_segment)
df
df.groupby('PriceSegment')['StockCode'].nunique()
# Out:
# PriceSegment
# cheap           3425
# expensive         14
# lower-middle    1530
# upper-middle      97
# Name: StockCode, dtype: int64

# %% [markdown]
# #### Практика. Определить, какая из категорий товаров принесла больше всего выручки

# %%
df.groupby('PriceSegment')['Revenue'].sum().sort_values(ascending = False)
# Out:
# PriceSegment
# cheap           7887707.804
# lower-middle    2280824.460
# expensive        374342.750
# upper-middle      99235.790
# Name: Revenue, dtype: float64

# %%
df.groupby('PriceSegment')['Revenue'].sum().sort_values(ascending=False).head(1)
# Out:
# PriceSegment
# cheap    7887707.804
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Как меняется средний чек со временем?

# %%
df.groupby('InvoiceMonth')['Revenue'].sum().divide(df.groupby('InvoiceMonth')['InvoiceNo'].nunique()).plot()

# %% [markdown]
# ### Построим сводные таблицы

# %%
# сводная таблица по выручки в определенной стране в разрезе клиентов и месяцев
country = 'France'
table = pd.pivot_table(
    df[df['Country']==country], 
    index='CustomerID', 
    columns='InvoiceMonth', 
    aggfunc='sum', 
    values='Revenue', 
    fill_value=0)


# подсветить максимальные значения по каждому месяцу
# table
# table.style.highlight_max()
table.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_1616e_row0_col0, #T_1616e_row0_col2, #T_1616e_row0_col3, #T_1616e_row0_col5, #T_1616e_row0_col6, #T_1616e_row0_col7, #T_1616e_row0_col8, #T_1616e_row0_col9, #T_1616e_row0_col11, #T_1616e_row0_col12, #T_1616e_row1_col0, #T_1616e_row1_col7, #T_1616e_row1_col8, #T_1616e_row2_col1, #T_1616e_row2_col2, #T_1616e_row2_col3, #T_1616e_row2_col4, #T_1616e_row2_col5, #T_1616e_row2_col6, #T_1616e_row2_col7, #T_1616e_row2_col8, #T_1616e_row2_col9, #T_1616e_row2_col10, #T_1616e_row2_col11, #T_1616e_row2_col12, #T_1616e_row3_col0, #T_1616e_row3_col1, #T_1616e_row3_col2, #T_1616e_row3_col3, #T_1616e_row3_col4, #T_1616e_row3_col5, #T_1616e_row3_col6, #T_1616e_row3_col7, #T_1616e_row3_col8, #T_1616e_row3_col12, #T_1616e_row4_col0, #T_1616e_row4_col2, #T_1616e_row4_col3, #T_1616e_row4_col4, #T_1616e_row4_col5, #T_1616e_row4_col6, #T_1616e_row4_col7, #T_1616e_row4_col8, #T_1616e_row4_col9, #T_1616e_row4_col10, #T_1616e_row4_col11, #T_1616e_row4_col12, #T_1616e_row5_col0, #T_1616e_row5_col2, #T_1616e_row5_col3, #T_1616e_row5_col4, #T_1616e_row5_col10, #T_1616e_row6_col0, #T_1616e_row6_col1, #T_1616e_row6_col2, #T_1616e_row6_col3, #T_1616e_row6_col4, #T_1616e_row6_col5, #T_1616e_row6_col6, #T_1616e_row6_col7, #T_1616e_row6_col8, #T_1616e_row6_col9, #T_1616e_row6_col10, #T_1616e_row6_col12, #T_1616e_row7_col0, #T_1616e_row7_col1, #T_1616e_row7_col2, #T_1616e_row7_col3, #T_1616e_row7_col4, #T_1616e_row7_col7, #T_1616e_row7_col8, #T_1616e_row7_col9, #T_1616e_row7_col10, #T_1616e_row7_col11, #T_1616e_row7_col12, #T_1616e_row8_col1, #T_1616e_row8_col3, #T_1616e_row8_col4, #T_1616e_row8_col6, #T_1616e_row8_col8, #T_1616e_row8_col9, #T_1616e_row8_col12, #T_1616e_row9_col0, #T_1616e_row9_col1, #T_1616e_row9_col2, #T_1616e_row9_col3, #T_1616e_row9_col5, #T_1616e_row9_col6, #T_1616e_row9_col7, #T_1616e_row9_col8, #T_1616e_row9_col9, #T_1616e_row9_col10, #T_1616e_row9_col11, #T_1616e_row9_col12, #T_1616e_row10_col0, #T_1616e_row10_col1, #T_1616e_row10_col2, #T_1616e_row10_col3, #T_1616e_row10_col4, #T_1616e_row10_col5, #T_1616e_row10_col6, #T_1616e_row10_col7, #T_1616e_row10_col8, #T_1616e_row10_col9, #T_1616e_row10_col10, #T_1616e_row10_col12, #T_1616e_row11_col0, #T_1616e_row11_col1, #T_1616e_row11_col3, #T_1616e_row11_col4, #T_1616e_row11_col5, #T_1616e_row11_col6, #T_1616e_row11_col7, #T_1616e_row11_col8, #T_1616e_row11_col9, #T_1616e_row11_col10, #T_1616e_row11_col11, #T_1616e_row11_col12, #T_1616e_row12_col0, #T_1616e_row12_col1, #T_1616e_row12_col2, #T_1616e_row12_col3, #T_1616e_row12_col4, #T_1616e_row12_col5, #T_1616e_row12_col6, #T_1616e_row12_col7, #T_1616e_row12_col9, #T_1616e_row12_col10, #T_1616e_row12_col11, #T_1616e_row12_col12, #T_1616e_row13_col0, #T_1616e_row13_col5, #T_1616e_row13_col6, #T_1616e_row13_col12, #T_1616e_row14_col0, #T_1616e_row14_col1, #T_1616e_row14_col2, #T_1616e_row14_col3, #T_1616e_row14_col4, #T_1616e_row14_col5, #T_1616e_row14_col6, #T_1616e_row14_col7, #T_1616e_row14_col8, #T_1616e_row14_col9, #T_1616e_row14_col10, #T_1616e_row14_col12, #T_1616e_row15_col0, #T_1616e_row15_col1, #T_1616e_row15_col2, #T_1616e_row15_col3, #T_1616e_row15_col4, #T_1616e_row15_col5, #T_1616e_row15_col7, #T_1616e_row15_col8, #T_1616e_row15_col10, #T_1616e_row15_col11, #T_1616e_row15_col12, #T_1616e_row16_col0, #T_1616e_row16_col1, #T_1616e_row16_col2, #T_1616e_row16_col3, #T_1616e_row16_col4, #T_1616e_row16_col5, #T_1616e_row16_col6, #T_1616e_row16_col7, #T_1616e_row16_col8, #T_1616e_row16_col9, #T_1616e_row16_col11, #T_1616e_row16_col12, #T_1616e_row17_col0, #T_1616e_row17_col4, #T_1616e_row17_col6, #T_1616e_row17_col9, #T_1616e_row18_col0, #T_1616e_row18_col1, #T_1616e_row18_col2, #T_1616e_row18_col3, #T_1616e_row18_col4, #T_1616e_row18_col7, #T_1616e_row19_col0, #T_1616e_row19_col1, #T_1616e_row19_col2, #T_1616e_row19_col4, #T_1616e_row19_col5, #T_1616e_row19_col6, #T_1616e_row19_col7, #T_1616e_row19_col8, #T_1616e_row19_col9, #T_1616e_row19_col10, #T_1616e_row19_col11, #T_1616e_row19_col12, #T_1616e_row20_col1, #T_1616e_row20_col3, #T_ ...

# %% [markdown]
# #### Практика. Построить сводную таблицу c кол-вом заказов по странам и месяцам

# %%
new_table = pd.pivot_table(
df, 
index='Country', 
columns='InvoiceMonth', 
aggfunc='nunique', #ту мб np.Series.nunique
values='InvoiceNo', 
fill_value=0) 
new_table
# Out:
# InvoiceMonth          2010-12  2011-01  2011-02  2011-03  2011-04  2011-05  \
# Country
# Australia                   3        9        5        3        2        4
# Austria                     1        0        2        2        2        2
# Bahrain                     1        0        0        0        0        2
# Belgium                     5        3        8        9        6        9
# Brazil                      0        0        0        0        1        0
# Canada                      0        0        0        1        0        1
# Channel Islands             1        1        1        3        1        2
# Cyprus                      1        1        6        1        0        0
# Czech Republic              0        0        1        0        0        0
# Denmark                     1        0        1        1        0        1
# EIRE                       17        7       13       23       11       22
# European Community          0        0        0        0        1        0
# Finland                     1        2        1        5        4        0
# France                     21       29       21       25       14       39
# Germany                    30       31       19       32       23       42
# Greece                      0        1        0        1        1        0
# Hong Kong                   0        1        0        1        1        1
# Iceland                     1        1        0        0        1        0
# Israel                      0        1        1        0        1        0
# Italy                       2        3        1        4        2        1
# Japan                       3        0        2        3        2        1
# Lebanon                     0        1        0        0        0        0
# Lithuania                   4        0        0        0        0        0
# Malta                       0        0        0        0        0        0
# Netherlands                 3        5        5        8        3       11
# Norway                      2        0        2        4        0        0
# Poland                      1        1        2        1        1        3
# Portugal                    6        4        2        5        2        5
# RSA                         0        0        0        0        0        0
# Saudi Arabia                0        0        1        0        0        0
# Singapore                   0        1        0        0        3        0
# Spain                       4        8        4        8        3        4
# Sweden                      2        2        1        3        2        3
# Switzerland                 2        3        5        3        4        3
# USA                         0        0        0        0        1        0
# United Arab Emirates        0        0        1        0        0        0
# United Kingdom           1447      971      995     1308     1153     1523
# Unspecified                 0        0        0        0        1        2
#
# InvoiceMonth          2011-06  2011-07  2011-08  2011-09  2011-10  2011-11  \
# Country
# Australia                   4        7        2        8        4        6
# Austria                     0        2        2        0        1        2
# Bahrain                     0        0        0        0        0        0
# Belgium                    11        5        9        7       11       11
# Brazil                      0        0        0        0        0        0
# Canada                      1        2        1        0        0        0
# Channel Islands             1        0        5        2        5        3
# Cyprus                      1        0        0        1        4        1
# Czech Republic              0        0        0        0        1        0
# Denmark                     3        1        1        3        3        2
# EIRE                       28       27       19       38       31       42
# European Community          2        1        0        0        0        0
# Finland                     1        3        3        4        6        8
# France                     31       22       28       45       35       64
# Germany                    24       33       39       41       58       68
# Greece                      0        1        0        0        0        0
# Hong Kong                   1        0        2        1        2        1
# Iceland                     1        0        1        0        1        0
# Israel                      0        1        1        1        2        0
# Italy                       2        1        4        1        7        9
# Japan                       1        2        0        1        2        2
# Lebanon                     0        0        0        0        0        0
# Lithuania                   0        0        0        0        0        0
# Malta                       2        0        2        0        0        1
# Netherlands                11        1        7        7       15       15
# Norway                      4        1        2        6        7        5
# Poland                      2        2        2        2        0        2
# Portugal                    3        3        1        3       10       10
# RSA                         0        0        0        0        1        0
# Saudi Arabia                0        0        0        0        0        0
# Singapore                   0        1        0        0        2        0
# Spain                       8        9       10        8        8       14
# Sweden                      3        3        5        3        3        5
# Switzerland                 4        6        3        7        8        6
# USA                         0        0        0        0        2        0
# United Arab Emirates        0        0        0        2        0        0
# United Kingdom           1383     1337     1210     1645     1811     2490
# Unspecified                 1        4        2        1        0        2
#
# InvoiceMonth          2011-12
# Country
# Australia                   0
# Austria                     1
# Bahrain                     0
# Belgium                     4
# Brazil                      0
# Canada                      0
# Channel Islands             1
# Cyprus                      0
# Czech Republic              0
# Denmark                     1
# EIRE                       10
# European Community          0
# Finland                     3
# France                     18
# Germany                    17
# Greece                      1
# Hong Kong                   0
# Iceland                     1
# Israel                      0
# Italy                       1
# Japan                       0
# Lebanon                     0
# Lithuania                   0
# Malta                       0
# Netherlands                 3
# Norway                      3
# Poland                      0
# Portugal                    4
# RSA                         0
# Saudi Arabia                0
# Singapore                   0
# Spain                       2
# Sweden                      1
# Switzerland                 0
# USA                         2
# United Arab Emirates        0
# United Kingdom            746
# Unspecified                 0

# %%
# изучим сводную статистику по покупателям из произвольной страны (суммарная и средняя выручка)
products = df[df['Country']==country].groupby(['CustomerID', 'InvoiceNo'], as_index=False)['Revenue'].sum()
display(products)
products = products.groupby('CustomerID').agg({'InvoiceNo': ['count'], 'Revenue': ['sum','mean']})
display(products)
# Out:
#      CustomerID InvoiceNo  Revenue
# 0         12413    540365   479.25
# 1         12413    550338    84.65
# 2         12413    569402   194.20
# 3         12437    540972   392.70
# 4         12437    543030   150.50
# ..          ...       ...      ...
# 384       12736    540688   234.00
# 385       12740    570030   427.60
# 386       14277    552826  1629.03
# 387       14277    577152   499.40
# 388       14277    578541  2059.57
#
# [389 rows x 3 columns]
#            InvoiceNo  Revenue
#                count      sum         mean
# CustomerID
# 12413              3   758.10   252.700000
# 12437             18  4951.41   275.078333
# 12441              1   173.55   173.550000
# 12488              3  1298.66   432.886667
# 12489              1   334.93   334.930000
# ...              ...      ...          ...
# 12734              1   110.40   110.400000
# 12735              2   779.57   389.785000
# 12736              1   234.00   234.000000
# 12740              1   427.60   427.600000
# 14277              3  4188.00  1396.000000
#
# [87 rows x 3 columns]

# %%
# объединяем статистику по месяцам и статистику по выручки и количеству заказов в разрезе пользователей
table_plus = pd.merge(table, products, on='CustomerID') 
table_plus.style.highlight_max()
# table_plus.style.background_gradient(cmap='PuBu')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
# <style type="text/css">
# #T_a51e9_row16_col10, #T_a51e9_row16_col15, #T_a51e9_row20_col2, #T_a51e9_row20_col6, #T_a51e9_row48_col4, #T_a51e9_row52_col3, #T_a51e9_row52_col8, #T_a51e9_row55_col0, #T_a51e9_row56_col13, #T_a51e9_row66_col12, #T_a51e9_row80_col1, #T_a51e9_row80_col7, #T_a51e9_row80_col9, #T_a51e9_row80_col14, #T_a51e9_row86_col5, #T_a51e9_row86_col11 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a51e9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2010-12</th>
#       <th class="col_heading level0 col1" >2011-01</th>
#       <th class="col_heading level0 col2" >2011-02</th>
#       <th class="col_heading level0 col3" >2011-03</th>
#       <th class="col_heading level0 col4" >2011-04</th>
#       <th class="col_heading level0 col5" >2011-05</th>
#       <th class="col_heading level0 col6" >2011-06</th>
#       <th class="col_heading level0 col7" >2011-07</th>
#       <th class="col_heading level0 col8" >2011-08</th>
#       <th class="col_heading level0 col9" >2011-09</th>
#       <th class="col_heading level0 col10" >2011-10</th>
#       <th class="col_heading level0 col11" >2011-11</th>
#       <th class="col_heading level0 col12" >2011-12</th>
#       <th class="col_heading level0 col13" >('InvoiceNo', 'count')</th>
#       <th class="col_heading level0 col14" >('Revenue', 'sum')</th>
#       <th class="col_heading level0 col15" >('Revenue', 'mean')</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CustomerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a51e9_level0_row0" class="row_heading level0 row0" >12413</th>
#       <td id="T_a51e9_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_a51e9_row0_col1" class="data row0 col1" >479.250000</td>
#       <td id="T_a51e9_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_a51e9_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a51e9_row0_col4" class="data row0 col4" >84.650000</td>
#       <td id="T_a51e9_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_a51e9_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_a51e9_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_a51e9_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_a51e9_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_a51e9_row0_col10" class="data row0 col10" >194.200000</td>
#       <td id="T_a51e9_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_a51e9_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_a51e9_row0_col13" class="data row0 col13" >3</td>
#       <td id="T_a51e9_row0_col14" class="data row0 col14" >758.100000</td>
#       <td id="T_a51e9_row0_col15" class="data row0 col15" >252.700000</td>
#     </tr>
#     <tr>
#       <th id="T_a51e9_level0_row1" class="row_heading level0 row1" >12437</th>
#       <td id="T_a51e9_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a51e9_row1_col1" class="data row1 col1" >392.700000</td>
#       <td id="T_a51e9_row1_col2" class="data row1 col2" >590.260000</td>
#       <td id="T_a51e9_row1_col3" class="data row1 col3" >147.710000</td>
#       <td id="T_a51e9_row1_col4" class="data row1 col4" >209.100000</td>
#       <td id="T_a51e9_row1_col5" class="data row1 col5" >635.320000</td>
#       <td id="T_a51e9_row1_col6" class="data row1 col6" >501.640000</td>
#       <td id="T_a51e9_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_a51e9_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_a51e9_row1_col9" class="data row1 col9" >557.280000</td>
#       <td id="T_a51e9_row1_col10" class="data row1 col10" >263.460000</td>
#       <td id="T_a51e9_row1_col11" class="data row1 col11" >1488.040000</td>
#       <td id="T_a51e9_row1_col12" class="data row1 col12" >165.900000</td>
#       <td id="T_a51e9_row1_col13" class="data row1 col13" >18</td>
#       <td id="T_a51e9_row1_col14" class="data row1 col14" >4951.410000</td>
#       <td id="T_a51e9_row1_col15" class="data row1 col15" >275.078333</td>
#     </tr>
#     <tr>
#       <th id="T_a51e9_level0_row2" class="row_heading level0 row2" >12441</th>
#       <td id="T_a51e9_row2_col0" class="data row2 col0" >173.550000</td>
#       <td id="T_a51e9_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_a51e9_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_a51e9_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a51e9_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_a51e9_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_a51e9_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_a51e9_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_a51e9_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_a51e9_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_a51e9_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_a51e9_row2_col11" class="data row2 col11" >0.000000</td>
#       <td id="T_a51e9_row2_col12" class="data row2 col12" >0.000000</td>
#       <td id="T_a51e9_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_a51e9_row2_col14" class="data row2 col14" >173.550000</td>
#       <td id="T_a51e9_row2_col15" class="data row2 col15" >173.550000</td>
#     </tr>
#     <tr>
#       <th id="T_a51e9_level0_row3" class="row_heading level0 row3" >12488</th>
#       <td id="T_a51e9_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_a51e9_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a51e9_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_a51e9_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a51e9_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_a51e9_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_a51e9_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_a51e9_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_a51e9_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_a51e9_row3_col9" class="data row3 col9" >553.390000</td>
#       <td id="T_a51e9_row3_col10" class="data row3 col10" >214.060000</td>
#       <td id="T_a51e9_row3_col11" class="data row3 col11" >531.210000</td>
#       <td id="T_a51e9_row3_col12" class="data row3 col12" >0.000000</td>
#       <td id="T_a51e9_row3_col13" class="data row3 col13" >3</td>
#       <td id="T_a51e9_row3_col14" class="data row3 col14" >1298.660000</td>
#       <td id="T_a51e9_row3_col15" class="data row3 col15" >432.886667</td>
#     </tr>
#     <tr>
#       <th id="T_a51e9_level0_row4" class="row_heading level0 row4" >12489</th>
#       <td id="T_a51e9_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_a51e9_row4_col1" class="data row4 col1" >334.930000</td>
#       <td id="T_a51e9_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_a51e9_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a51e9_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_a51e9_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_a51e9_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_a51e9_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="T_a51e9_row4_col8" class="data row4 col8" >0.000000</td>
#       <td id="T_a51e9_row4_col9"

# %%
pd.to_sql(df, con, name)

# %% [markdown]
# ### Когортный анализ
#
# Идея когортного анализа состоит в том, чтобы резделить клиентов на группы по определенным признакам, и отслеживать поведение этих групп во времени. Обычно группы пользователей (когорты) выделяют на основе недели (месяца), когда пользователи совершили первую покупку.
#
# Выделив такие группы пользователей (когорты), вы следите за ними в течение времени и измеряете ключевые метрики для каждой отдельной когорты.

# %%
# определяем месяц первой покупки для каждого покупателя 
cohorts = df.groupby('CustomerID', as_index=False)['InvoiceMonth'].min()
cohorts.rename(columns = {'InvoiceMonth':'Cohort'}, inplace=True)
cohorts.head()
# Out:
#    CustomerID   Cohort
# 0       12346  2011-01
# 1       12347  2010-12
# 2       12348  2010-12
# 3       12349  2011-11
# 4       12350  2011-02

# %%
# добавим когорты к основным данным

# исключаем пропуски по пользователям для корректного объединения
df_merged = pd.merge(df.dropna(), cohorts, how='left', on='CustomerID')
df_merged.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country InvoiceMonth  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom      2010-12
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom      2010-12
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom      2010-12
#
#    DayOfWeek  DayHour  InvoiceHour  Revenue PriceSegment   Cohort
# 0          3        8            8    15.30        cheap  2010-12
# 1          3        8            8    20.34        cheap  2010-12
# 2          3        8            8    22.00        cheap  2010-12
# 3          3        8            8    20.34        cheap  2010-12
# 4          3        8            8    20.34        cheap  2010-12

# %%
# считаем доходы по когортам
df_merged.groupby('Cohort')['Revenue'].sum().plot(kind='bar')

# %% [markdown]
# ### Анализ retention
#
# Customer retention (удержание клиентов) — это способность компании удерживать своих потребителей в течение определенного периода времени.

# %%
import numpy as np

# пишем функцию которая добавляет столбец с временем жизни каждой когорты
def cohort_period(df):
  df['CohortLT'] = np.arange(len(df))
  return df

# считаем сколько уникальных клиентов у нас в каждой когорте
cohorts = df_merged.groupby(['Cohort', 'InvoiceMonth'])[['CustomerID']].nunique()
cohorts = cohorts.groupby(level=0).apply(cohort_period)
cohorts.rename({'CustomerID': 'TotalUsers'}, inplace=True)
cohorts
# Out:
#                       CustomerID  CohortLT
# Cohort  InvoiceMonth
# 2010-12 2010-12              885         0
#         2011-01              324         1
#         2011-02              286         2
#         2011-03              340         3
#         2011-04              321         4
# ...                          ...       ...
# 2011-10 2011-11               86         1
#         2011-12               41         2
# 2011-11 2011-11              323         0
#         2011-12               36         1
# 2011-12 2011-12               41         0
#
# [91 rows x 2 columns]

# %%
# переведем когорты в индекс, а дату чека в столбец
cohorts.reset_index(inplace=True)
cohorts.set_index(['Cohort', 'CohortLT'], inplace=True) 
cohorts = cohorts.rename(columns={'CustomerID': 'TotalUsers'})
cohorts
# Out:
#                  InvoiceMonth  TotalUsers
# Cohort  CohortLT
# 2010-12 0             2010-12         885
#         1             2011-01         324
#         2             2011-02         286
#         3             2011-03         340
#         4             2011-04         321
# ...                       ...         ...
# 2011-10 1             2011-11          86
#         2             2011-12          41
# 2011-11 0             2011-11         323
#         1             2011-12          36
# 2011-12 0             2011-12          41
#
# [91 rows x 2 columns]

# %%
# считаем ретеншн пользователей в каждой когорте

# определим количество покупок в первый месяц когорты (100%)
cohort_group_size = cohorts['TotalUsers'].groupby(level=0).first()
cohort_group_size
# Out:
# Cohort
# 2010-12    885
# 2011-01    417
# 2011-02    380
# 2011-03    452
# 2011-04    300
# 2011-05    284
# 2011-06    242
# 2011-07    188
# 2011-08    169
# 2011-09    299
# 2011-10    358
# 2011-11    323
# 2011-12     41
# Name: TotalUsers, dtype: int64

# %%
# узнаем какой процент покупок этой когортой совершался в последующие месяца
user_retention = cohorts['TotalUsers'].unstack(0).divide(cohort_group_size, axis=1)
user_retention
# Out:
# Cohort     2010-12   2011-01   2011-02   2011-03   2011-04   2011-05  \
# CohortLT
# 0         1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1         0.366102  0.220624  0.186842  0.150442  0.213333  0.190141
# 2         0.323164  0.266187  0.186842  0.252212  0.203333  0.172535
# 3         0.384181  0.230216  0.284211  0.199115  0.210000  0.172535
# 4         0.362712  0.321343  0.271053  0.223451  0.196667  0.207746
# 5         0.397740  0.287770  0.247368  0.168142  0.226667  0.232394
# 6         0.362712  0.247002  0.252632  0.267699  0.216667  0.264085
# 7         0.349153  0.242206  0.278947  0.230088  0.260000  0.095070
# 8         0.353672  0.299760  0.247368  0.278761  0.073333       NaN
# 9         0.395480  0.326139  0.305263  0.086283       NaN       NaN
# 10        0.374011  0.364508  0.068421       NaN       NaN       NaN
# 11        0.502825  0.117506       NaN       NaN       NaN       NaN
# 12        0.265537       NaN       NaN       NaN       NaN       NaN
#
# Cohort     2011-06   2011-07   2011-08   2011-09   2011-10   2011-11  2011-12
# CohortLT
# 0         1.000000  1.000000  1.000000  1.000000  1.000000  1.000000      1.0
# 1         0.173554  0.180851  0.207101  0.234114  0.240223  0.111455      NaN
# 2         0.157025  0.207447  0.248521  0.301003  0.114525       NaN      NaN
# 3         0.264463  0.223404  0.242604  0.113712       NaN       NaN      NaN
# 4         0.231405  0.271277  0.124260       NaN       NaN       NaN      NaN
# 5         0.334711  0.111702       NaN       NaN       NaN       NaN      NaN
# 6         0.095041       NaN       NaN       NaN       NaN       NaN      NaN
# 7              NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 8              NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 9              NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 10             NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 11             NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 12             NaN       NaN       NaN       NaN       NaN       NaN      NaN

# %% [markdown]
# **Спасибо за внимание буду рад ответить на ваши вопросы!**
# Ссылка на форму ОС:
# https://skillfactoryschool.typeform.com/to/wY5lRTGh?typeform-source=www.google.com

# %%
import sqlalchemy
engine = sqlalchemy.create_engine('адрес БД')
conn = engine.connect()

# %%
data = pd.read_csv('diabetes.csv')
data

# %%
data.to_sql(name='diabetes', con=conn, index=False, if_exists='replace')

# %%
diabetes = pd.read_sql('select * from diabetes;', conn)
conn.close()
diabetes
